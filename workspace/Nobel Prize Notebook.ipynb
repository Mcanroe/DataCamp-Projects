# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', None)

# %% [markdown]
# # **DataCamp questions to answer:**
# 1.  What is the most commonly awarded gender and birth country?
# 2.  Which decade had the highest ratio of US-born Nobel Prize winners to total winners in all categories?
# 3.  Which decade and Nobel Prize category combination had the highest proportion of female laureates?
# 4.  Who was the first woman to receive a Nobel Prize, and in what category?
# 5.  Which individuals or organizations have won more than one Nobel Prize throughout the years?

# %%
#Importing csv
nobel = pd.read_csv("data/nobel.csv")
nobel.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %%
#Exploring Data
print(nobel.info())
print(nobel.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  1000 non-null   int64
#  1   category              1000 non-null   object
#  2   prize                 1000 non-null   object
#  3   motivation            912 non-null    object
#  4   prize_share           1000 non-null   object
#  5   laureate_id           1000 non-null   int64
#  6   laureate_type         1000 non-null   object
#  7   full_name             1000 non-null   object
#  8   birth_date            968 non-null    object
#  9   birth_city            964 non-null    object
#  10  birth_country         969 non-null    object
#  11  sex                   970 non-null    object
#  12  organization_name     736 non-null    object
#  13  organization_city     735 non-null    object
#  14  organization_country  735 non-null    object
# ...

# %%
#Answering Question 1 - What is the most commonly awarded gender and birth country?
top_gender = nobel['sex'].value_counts().idxmax()
top_country = nobel['birth_country'].value_counts().idxmax()
print(top_gender)
print(top_country)
# Out:
# Male
# United States of America

# %%
#Simple visualisations to answer the same questions
sns.catplot(x='sex',data=nobel,kind='count')
plt.title('Sex Count Of Nobel Prize Winners')
plt.show()

#Creating a dataframe with top 3 countries
bc_counts = nobel['birth_country'].value_counts().sort_values(ascending = False)
top3 = bc_counts.head(3).index
bc_sorted = nobel[nobel['birth_country'].isin(top3)]
sns.catplot(x='birth_country', data=bc_sorted,kind='count', order=top3)
plt.title('Top Birth Countries of Nobel Prize Winners')
plt.xticks(fontsize=8) #adjusting x-axis for better readability
plt.show()

# %%
#Answering Question 2 - Which decade had the highest ratio of US-born Nobel Prize winners to total winners in all categories?

nobel['decade'] = (np.floor((nobel['year']/10)) * 10).astype(int)
nobel['usa_flag'] = nobel['birth_country']=='United States of America'
nobel_grouped = nobel.groupby('decade', as_index=False)['usa_flag'].mean()
max_decade_usa = nobel_grouped[nobel_grouped['usa_flag'] == nobel_grouped['usa_flag'].max()].values[0,0]

# %%
#Visualising answer to Question 2

sns.relplot(x='decade', y='usa_flag', data=nobel_grouped, kind='line')
plt.title('US-born Nobel Prize Winners over the decades')
plt.xlabel('Decade')
plt.ylabel('Ratio of US-born Nobel Prize Winners')
# Out:
# Text(0.6944444444444446, 0.5, 'Ratio of US-born Nobel Prize Winners')

# %%
#Answering Question 3
nobel.loc[:,'Female_Winner'] = (nobel['sex'] == 'Female')
nobel_women_grouped = nobel.groupby(['decade','category'], as_index=False)['Female_Winner'].mean()
nobel_women_max = nobel_women_grouped[nobel_women_grouped['Female_Winner'] == nobel_women_grouped['Female_Winner'].max()]
max_female_dict = {nobel_women_max.iloc[0,0],nobel_women_max.iloc[0,1]}
print(max_female_dict)
# Out:
# {np.int64(2020), 'Literature'}

# %%
#Visualising Answer to Question 3 - Which decade and Nobel Prize category combination had the highest proportion of female laureates?
sns.relplot(x='decade', y='Female_Winner',hue='category', data=nobel_women_grouped, kind='line')
plt.title('Female Winners for Each Category over the Decades', loc='left')
plt.xlabel('Decade')
plt.ylabel('Ratio of Female Winners')
plt.show()

# %%
#Answering Question 4 - Who was the first woman to receive a Nobel Prize, and in what category?
nobel_women_sorted = nobel[nobel['sex'] == 'Female'].sort_values(by='year')
first_woman_name = nobel_women_sorted.iloc[0]['full_name']
first_woman_category = nobel_women_sorted.iloc[0]['category']

print(first_woman_name,first_woman_category)
# Out:
# Marie Curie, née Sklodowska Physics
